# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
from numpy import array
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
 
 
# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()


df1 = pd.read_csv("/content/gdrive/My Drive/ampds/data/data.csv")
from sklearn.model_selection import train_test_split
import tensorflow as tf

X=df1.iloc[:524540,1:2]
for j in range(2,21):
  print("------------------------------------------------------------------------------")
  y=df1.iloc[:524540,j:j+1]
  # print(y)
  l=[]
  for i in range(0,524540):
    chk=i%86400
    if(chk<21600):
      l.append(0)
    elif (21600<=chk<43200):
      l.append(1)
    elif (43200<=chk<64800):
      l.append(2)
    else:
      l.append(3)
  encoded = to_categorical(l)
  dataset = pd.DataFrame({'N': encoded[:, 0], 'M': encoded[:, 1], 'A': encoded[:, 2], 'E': encoded[:, 3]})
  # print(dataset.head())

  df = pd.concat([X, dataset], axis=1)
  # print(df.head())
  import matplotlib.pyplot as plt
  plt.plot(df)
  plt.show()

  dataset = df.values
  dataset = df.astype('float32')
  scaler = MinMaxScaler(feature_range=(0, 1))
  dataset = scaler.fit_transform(dataset)
  # print (dataset)
  # print (dataset.shape)

  datay = y.values
  datay = y.astype('float32')
  scaler = MinMaxScaler(feature_range=(0, 1))
  datay = scaler.fit_transform(datay)
  # print (datay)
  # print(datay.shape)

  dataset = dataset.reshape((dataset.shape[0], 1, dataset.shape[1], 1))
  # print(dataset.shape)
  from sklearn.model_selection import train_test_split
  X_train, X_test, y_train, y_test = train_test_split(dataset, datay, test_size=0.10)
  # print(X_train.shape)
  # print(y_train.shape)

  y_test = pd.DataFrame(y_test, columns=['y_test'])
  y_test.to_csv('cnn-lstm-test'+str(j)+'.csv') 

  model = Sequential()
  model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=( 1,5,1)))
  model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
  model.add(TimeDistributed(Flatten()))
  model.add(LSTM(50, activation='relu'))
  model.add(Dense(1))
  model.compile(optimizer='adam', loss='mse')

  history=model.fit(X_train, y_train, epochs=10, batch_size=72, validation_data=(X_test, y_test), verbose=2, shuffle=False)
  from matplotlib import pyplot
  pyplot.plot(history.history['loss'], label='train')
  pyplot.plot(history.history['val_loss'], label='test')
  pyplot.legend()
  pyplot.show()

  from math import sqrt
  from numpy import concatenate

  yhat = model.predict(X_test)
  yhat = pd.DataFrame(yhat, columns=['yhat'])
  yhat.to_csv('cnn-lstm-predict'+str(j)+'.csv') 
  #X_test = X_test.reshape((X_test.shape[0], X_test.shape[1]))
  # invert scaling for forecast
  # inv_yhat = concatenate((yhat, test[:, 1:]), axis=1)
  # inv=inv_yhat
  # inv_yhat = scaler.inverse_transform(inv_yhat)
  # inv_yhat = inv_yhat[:,0]
  # # invert scaling for actual
  # testy = testy.reshape((len(testy), 1))
  # inv_y = concatenate((testy, test[:, 1:]), axis=1)
  rmse = sqrt(mean_squared_error(y_test, yhat))
  print('Test RMSE: %.3f' % rmse)
  # inv_y = scaler.inverse_transform(inv_y)
  # inv_y = inv_y[:,0]
  # # calculate RMSE
  # rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
  # print('Test RMSE: %.3f' % rmse)
# Out:
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 26s - loss: 5.0769e-04 - val_loss: 4.5677e-04
# Epoch 2/10
#  - 25s - loss: 5.0385e-04 - val_loss: 4.5422e-04
# Epoch 3/10
#  - 25s - loss: 5.0348e-04 - val_loss: 4.5350e-04
# Epoch 4/10
#  - 25s - loss: 5.0330e-04 - val_loss: 4.5350e-04
# Epoch 5/10
#  - 25s - loss: 5.0317e-04 - val_loss: 4.5323e-04
# Epoch 6/10
#  - 26s - loss: 5.0306e-04 - val_loss: 4.5322e-04
# Epoch 7/10
#  - 25s - loss: 5.0303e-04 - val_loss: 4.5294e-04
# Epoch 8/10
#  - 24s - loss: 5.0299e-04 - val_loss: 4.5289e-04
# Epoch 9/10
#  - 24s - loss: 5.0292e-04 - val_loss: 4.5221e-04
# Epoch 10/10
#  - 25s - loss: 5.0292e-04 - val_loss: 4.5276e-04
# Test RMSE: 0.021
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 26s - loss: 8.3493e-04 - val_loss: 8.0602e-04
# Epoch 2/10
#  - 25s - loss: 8.1373e-04 - val_loss: 7.9983e-04
# Epoch 3/10
#  - 25s - loss: 8.0779e-04 - val_loss: 7.9347e-04
# Epoch 4/10
#  - 25s - loss: 8.0443e-04 - val_loss: 7.9222e-04
# Epoch 5/10
#  - 25s - loss: 8.0300e-04 - val_loss: 7.9033e-04
# Epoch 6/10
#  - 24s - loss: 8.0167e-04 - val_loss: 7.8899e-04
# Epoch 7/10
#  - 25s - loss: 8.0008e-04 - val_loss: 7.8727e-04
# Epoch 8/10
#  - 25s - loss: 7.9887e-04 - val_loss: 7.8661e-04
# Epoch 9/10
#  - 25s - loss: 7.9787e-04 - val_loss: 7.8615e-04
# Epoch 10/10
#  - 25s - loss: 7.9736e-04 - val_loss: 7.8588e-04
# Test RMSE: 0.028
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 26s - loss: 0.0039 - val_loss: 0.0038
# Epoch 2/10
#  - 25s - loss: 0.0035 - val_loss: 0.0034
# Epoch 3/10
#  - 24s - loss: 0.0033 - val_loss: 0.0033
# Epoch 4/10
#  - 25s - loss: 0.0033 - val_loss: 0.0033
# Epoch 5/10
#  - 24s - loss: 0.0033 - val_loss: 0.0033
# Epoch 6/10
#  - 25s - loss: 0.0033 - val_loss: 0.0032
# Epoch 7/10
#  - 24s - loss: 0.0032 - val_loss: 0.0032
# Epoch 8/10
#  - 24s - loss: 0.0032 - val_loss: 0.0032
# Epoch 9/10
#  - 24s - loss: 0.0032 - val_loss: 0.0032
# Epoch 10/10
#  - 24s - loss: 0.0032 - val_loss: 0.0032
# Test RMSE: 0.056
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 27s - loss: 0.0032 - val_loss: 0.0019
# Epoch 2/10
#  - 25s - loss: 0.0016 - val_loss: 0.0013
# Epoch 3/10
#  - 25s - loss: 6.7263e-04 - val_loss: 4.3665e-04
# Epoch 4/10
#  - 25s - loss: 4.4842e-04 - val_loss: 3.8053e-04
# Epoch 5/10
#  - 25s - loss: 4.1065e-04 - val_loss: 3.6395e-04
# Epoch 6/10
#  - 25s - loss: 3.9203e-04 - val_loss: 3.8529e-04
# Epoch 7/10
#  - 25s - loss: 3.7874e-04 - val_loss: 3.5644e-04
# Epoch 8/10
#  - 25s - loss: 3.6959e-04 - val_loss: 3.4590e-04
# Epoch 9/10
#  - 24s - loss: 3.6266e-04 - val_loss: 3.3925e-04
# Epoch 10/10
#  - 24s - loss: 3.5673e-04 - val_loss: 3.3485e-04
# Test RMSE: 0.018
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 26s - loss: 0.0012 - val_loss: 0.0013
# Epoch 2/10
#  - 24s - loss: 0.0012 - val_loss: 0.0013
# Epoch 3/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Epoch 4/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Epoch 5/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Epoch 6/10
#  - 24s - loss: 0.0012 - val_loss: 0.0013
# Epoch 7/10
#  - 24s - loss: 0.0012 - val_loss: 0.0013
# Epoch 8/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Epoch 9/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Epoch 10/10
#  - 25s - loss: 0.0012 - val_loss: 0.0013
# Test RMSE: 0.036
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 27s - loss: 0.0026 - val_loss: 0.0025
# Epoch 2/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 3/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 4/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 5/10
#  - 26s - loss: 0.0026 - val_loss: 0.0025
# Epoch 6/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 7/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 8/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 9/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Epoch 10/10
#  - 25s - loss: 0.0026 - val_loss: 0.0025
# Test RMSE: 0.050
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 28s - loss: 0.0146 - val_loss: 0.0139
# Epoch 2/10
#  - 26s - loss: 0.0140 - val_loss: 0.0137
# Epoch 3/10
#  - 25s - loss: 0.0139 - val_loss: 0.0137
# Epoch 4/10
#  - 26s - loss: 0.0138 - val_loss: 0.0137
# Epoch 5/10
#  - 25s - loss: 0.0138 - val_loss: 0.0136
# Epoch 6/10
#  - 25s - loss: 0.0137 - val_loss: 0.0135
# Epoch 7/10
#  - 26s - loss: 0.0136 - val_loss: 0.0134
# Epoch 8/10
#  - 25s - loss: 0.0136 - val_loss: 0.0134
# Epoch 9/10
#  - 25s - loss: 0.0135 - val_loss: 0.0133
# Epoch 10/10
#  - 25s - loss: 0.0135 - val_loss: 0.0134
# Test RMSE: 0.116
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 28s - loss: 0.0027 - val_loss: 0.0027
# Epoch 2/10
#  - 27s - loss: 0.0026 - val_loss: 0.0027
# Epoch 3/10
#  - 26s - loss: 0.0026 - val_loss: 0.0026
# Epoch 4/10
#  - 26s - loss: 0.0026 - val_loss: 0.0026
# Epoch 5/10
#  - 26s - loss: 0.0026 - val_loss: 0.0026
# Epoch 6/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 7/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 8/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 9/10
#  - 27s - loss: 0.0025 - val_loss: 0.0025
# Epoch 10/10
#  - 25s - loss: 0.0025 - val_loss: 0.0026
# Test RMSE: 0.051
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 29s - loss: 0.0054 - val_loss: 0.0026
# Epoch 2/10
#  - 26s - loss: 0.0026 - val_loss: 0.0026
# Epoch 3/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 4/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 5/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 6/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 7/10
#  - 26s - loss: 0.0025 - val_loss: 0.0026
# Epoch 8/10
#  - 25s - loss: 0.0025 - val_loss: 0.0026
# Epoch 9/10
#  - 25s - loss: 0.0025 - val_loss: 0.0026
# Epoch 10/10
#  - 25s - loss: 0.0025 - val_loss: 0.0025
# Test RMSE: 0.050
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 29s - loss: 0.0013 - val_loss: 0.0012
# Epoch 2/10
#  - 26s - loss: 0.0012 - val_loss: 0.0011
# Epoch 3/10
#  - 25s - loss: 0.0011 - val_loss: 0.0011
# Epoch 4/10
#  - 25s - loss: 0.0011 - val_loss: 0.0011
# Epoch 5/10
#  - 25s - loss: 0.0011 - val_loss: 0.0011
# Epoch 6/10
#  - 26s - loss: 0.0011 - val_loss: 0.0011
# Epoch 7/10
#  - 26s - loss: 0.0011 - val_loss: 0.0011
# Epoch 8/10
#  - 26s - loss: 0.0011 - val_loss: 0.0011
# Epoch 9/10
#  - 25s - loss: 0.0011 - val_loss: 0.0011
# Epoch 10/10
#  - 25s - loss: 0.0011 - val_loss: 0.0011
# Test RMSE: 0.033
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 29s - loss: 0.0025 - val_loss: 0.0021
# Epoch 2/10
#  - 26s - loss: 0.0022 - val_loss: 0.0021
# Epoch 3/10
#  - 26s - loss: 0.0021 - val_loss: 0.0020
# Epoch 4/10
#  - 26s - loss: 0.0020 - val_loss: 0.0020
# Epoch 5/10
#  - 27s - loss: 0.0020 - val_loss: 0.0019
# Epoch 6/10
#  - 27s - loss: 0.0020 - val_loss: 0.0019
# Epoch 7/10
#  - 27s - loss: 0.0020 - val_loss: 0.0019
# Epoch 8/10
#  - 27s - loss: 0.0020 - val_loss: 0.0019
# Epoch 9/10
#  - 26s - loss: 0.0020 - val_loss: 0.0019
# Epoch 10/10
#  - 26s - loss: 0.0019 - val_loss: 0.0019
# Test RMSE: 0.043
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 30s - loss: 7.0257e-05 - val_loss: 4.1396e-05
# Epoch 2/10
#  - 26s - loss: 6.9055e-05 - val_loss: 4.1401e-05
# Epoch 3/10
#  - 27s - loss: 6.8966e-05 - val_loss: 4.1401e-05
# Epoch 4/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 5/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 6/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 7/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 8/10
#  - 29s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 9/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Epoch 10/10
#  - 28s - loss: 6.8956e-05 - val_loss: 4.1401e-05
# Test RMSE: 0.006
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 31s - loss: 9.2475e-04 - val_loss: 8.6046e-04
# Epoch 2/10
#  - 28s - loss: 6.1520e-04 - val_loss: 4.4339e-04
# Epoch 3/10
#  - 28s - loss: 4.4503e-04 - val_loss: 4.3065e-04
# Epoch 4/10
#  - 27s - loss: 4.2081e-04 - val_loss: 3.9939e-04
# Epoch 5/10
#  - 28s - loss: 3.7399e-04 - val_loss: 3.5098e-04
# Epoch 6/10
#  - 27s - loss: 3.1784e-04 - val_loss: 3.1905e-04
# Epoch 7/10
#  - 27s - loss: 3.1009e-04 - val_loss: 3.1526e-04
# Epoch 8/10
#  - 28s - loss: 3.0444e-04 - val_loss: 3.1261e-04
# Epoch 9/10
#  - 28s - loss: 2.9973e-04 - val_loss: 3.1240e-04
# Epoch 10/10
#  - 27s - loss: 2.9754e-04 - val_loss: 3.1116e-04
# Test RMSE: 0.018
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 31s - loss: 0.0116 - val_loss: 0.0116
# Epoch 2/10
#  - 27s - loss: 0.0115 - val_loss: 0.0116
# Epoch 3/10
#  - 27s - loss: 0.0115 - val_loss: 0.0115
# Epoch 4/10
#  - 27s - loss: 0.0114 - val_loss: 0.0115
# Epoch 5/10
#  - 27s - loss: 0.0114 - val_loss: 0.0115
# Epoch 6/10
#  - 27s - loss: 0.0114 - val_loss: 0.0115
# Epoch 7/10
#  - 27s - loss: 0.0114 - val_loss: 0.0114
# Epoch 8/10
#  - 27s - loss: 0.0114 - val_loss: 0.0114
# Epoch 9/10
#  - 27s - loss: 0.0114 - val_loss: 0.0114
# Epoch 10/10
#  - 27s - loss: 0.0114 - val_loss: 0.0114
# Test RMSE: 0.107
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 32s - loss: 0.0010 - val_loss: 9.8628e-04
# Epoch 2/10
#  - 28s - loss: 9.8567e-04 - val_loss: 9.8692e-04
# Epoch 3/10
#  - 28s - loss: 9.8295e-04 - val_loss: 9.8694e-04
# Epoch 4/10
#  - 27s - loss: 9.8157e-04 - val_loss: 9.8292e-04
# Epoch 5/10
#  - 27s - loss: 9.7985e-04 - val_loss: 9.7940e-04
# Epoch 6/10
#  - 27s - loss: 9.7837e-04 - val_loss: 9.7895e-04
# Epoch 7/10
#  - 27s - loss: 9.7712e-04 - val_loss: 9.7712e-04
# Epoch 8/10
#  - 28s - loss: 9.7639e-04 - val_loss: 9.7620e-04
# Epoch 9/10
#  - 28s - loss: 9.7582e-04 - val_loss: 9.7550e-04
# Epoch 10/10
#  - 29s - loss: 9.7545e-04 - val_loss: 9.7518e-04
# Test RMSE: 0.031
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 34s - loss: 5.5020e-06 - val_loss: 1.1381e-10
# Epoch 2/10
#  - 31s - loss: 4.3300e-06 - val_loss: 2.4461e-10
# Epoch 3/10
#  - 31s - loss: 4.3217e-06 - val_loss: 2.6322e-10
# Epoch 4/10
#  - 30s - loss: 4.3119e-06 - val_loss: 6.9982e-11
# Epoch 5/10
#  - 30s - loss: 4.3109e-06 - val_loss: 7.9893e-14
# Epoch 6/10
#  - 31s - loss: 4.3126e-06 - val_loss: 3.6475e-13
# Epoch 7/10
#  - 31s - loss: 4.3117e-06 - val_loss: 8.2678e-24
# Epoch 8/10
#  - 31s - loss: 4.3101e-06 - val_loss: 0.0000e+00
# Epoch 9/10
#  - 31s - loss: 4.3088e-06 - val_loss: 0.0000e+00
# Epoch 10/10
#  - 31s - loss: 4.3075e-06 - val_loss: 0.0000e+00
# Test RMSE: 0.000
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 36s - loss: 0.0035 - val_loss: 0.0033
# Epoch 2/10
#  - 31s - loss: 0.0033 - val_loss: 0.0031
# Epoch 3/10
#  - 31s - loss: 0.0032 - val_loss: 0.0031
# Epoch 4/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Epoch 5/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Epoch 6/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Epoch 7/10
#  - 32s - loss: 0.0031 - val_loss: 0.0031
# Epoch 8/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Epoch 9/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Epoch 10/10
#  - 31s - loss: 0.0031 - val_loss: 0.0031
# Test RMSE: 0.056
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 37s - loss: 0.0496 - val_loss: 0.0479
# Epoch 2/10
#  - 31s - loss: 0.0473 - val_loss: 0.0479
# Epoch 3/10
#  - 31s - loss: 0.0472 - val_loss: 0.0479
# Epoch 4/10
#  - 31s - loss: 0.0472 - val_loss: 0.0480
# Epoch 5/10
#  - 32s - loss: 0.0472 - val_loss: 0.0480
# Epoch 6/10
#  - 32s - loss: 0.0472 - val_loss: 0.0480
# Epoch 7/10
#  - 31s - loss: 0.0472 - val_loss: 0.0480
# Epoch 8/10
#  - 31s - loss: 0.0471 - val_loss: 0.0480
# Epoch 9/10
#  - 31s - loss: 0.0471 - val_loss: 0.0479
# Epoch 10/10
#  - 31s - loss: 0.0471 - val_loss: 0.0479
# Test RMSE: 0.219
# ------------------------------------------------------------------------------
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/10
#  - 38s - loss: 0.0012 - val_loss: 0.0012
# Epoch 2/10
#  - 35s - loss: 0.0012 - val_loss: 0.0012
# Epoch 3/10
#  - 31s - loss: 0.0012 - val_loss: 0.0012
# Epoch 4/10
#  - 31s - loss: 0.0011 - val_loss: 0.0011
# Epoch 5/10
#  - 31s - loss: 0.0011 - val_loss: 0.0011
# Epoch 6/10
#  - 32s - loss: 0.0011 - val_loss: 0.0011
# Epoch 7/10
#  - 31s - loss: 0.0011 - val_loss: 0.0011
# Epoch 8/10
#  - 31s - loss: 0.0011 - val_loss: 0.0011
# Epoch 9/10
#  - 31s - loss: 0.0011 - val_loss: 0.0011
# Epoch 10/10
#  - 30s - loss: 0.0011 - val_loss: 0.0011
# Test RMSE: 0.033

# %%
from numpy import array
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
 
 
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


df = pd.read_csv("/content/gdrive/My Drive/ampds/data/data.csv")
from sklearn.model_selection import train_test_split
import tensorflow as tf

X=df.iloc[:524540,1:2]
y=df.iloc[:524540,3:4]
# print(y)
l=[]
for i in range(0,524540):
  chk=i%86400
  if(chk<21600):
    l.append(0)
  elif (21600<=chk<43200):
    l.append(1)
  elif (43200<=chk<64800):
    l.append(2)
  else:
    l.append(3)
encoded = to_categorical(l)
dataset = pd.DataFrame({'N': encoded[:, 0], 'M': encoded[:, 1], 'A': encoded[:, 2], 'E': encoded[:, 3]})
# print(dataset.head())

df = pd.concat([X, dataset], axis=1)
# print(df.head())
import matplotlib.pyplot as plt
plt.plot(df)
plt.show()

dataset = df.values
dataset = df.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# print (dataset)
print (dataset.shape)

datay = y.values
datay = y.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
datay = scaler.fit_transform(datay)
# print (datay)
# print(datay.shape)

dataset = dataset.reshape((dataset.shape[0], 1, dataset.shape[1], 1))
print(dataset.shape)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, datay, test_size=0.10)
print(X_train.shape)
print(y_train.shape)

model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=( 1,5,1)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

history=model.fit(X_train, y_train, epochs=10, batch_size=72, validation_data=(X_test, y_test), verbose=2, shuffle=False)
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

from math import sqrt
from numpy import concatenate

yhat = model.predict(X_test)
print(yhat)
#X_test = X_test.reshape((X_test.shape[0], X_test.shape[1]))
# invert scaling for forecast
# inv_yhat = concatenate((yhat, test[:, 1:]), axis=1)
# inv=inv_yhat
# inv_yhat = scaler.inverse_transform(inv_yhat)
# inv_yhat = inv_yhat[:,0]
# # invert scaling for actual
# testy = testy.reshape((len(testy), 1))
# inv_y = concatenate((testy, test[:, 1:]), axis=1)
rmse = sqrt(mean_squared_error(y_test, yhat))
print('Test RMSE: %.3f' % rmse)
# inv_y = scaler.inverse_transform(inv_y)
# inv_y = inv_y[:,0]
# # calculate RMSE
# rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
# print('Test RMSE: %.3f' % rmse)
# Out:
# (524540, 5)
# (524540, 1, 5, 1)
# (472086, 1, 5, 1)
# (472086, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 25s - loss: 8.2692e-04 - val_loss: 8.0509e-04
# Epoch 2/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9b3ef67ff930> in <module>()
#      89 model.compile(optimizer='adam', loss='mse')
#      90
# ---> 91 history=model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=2, shuffle=False)
#      92 from matplotlib import pyplot
#      93 pyplot.plot(history.history['loss'], label='train')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
home/debajit/Desktop/AMPDS

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
dataset = df.values
dataset = df.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
print (dataset)
print (dataset.shape)
# Out:
# [[0.58253361 1.         0.         0.         0.        ]
#  [0.58253361 1.         0.         0.         0.        ]
#  [0.5815739  1.         0.         0.         0.        ]
#  ...
#  [0.30998081 1.         0.         0.         0.        ]
#  [0.31381959 1.         0.         0.         0.        ]
#  [0.31285988 1.         0.         0.         0.        ]]

# %%
datay = y.values
datay = y.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datay = scaler.fit_transform(datay)
print (datay)
print(datay.shape)
# Out:
# [[0.08235294]
#  [0.10588235]
#  [0.10588235]
#  ...
#  [0.01176471]
#  [0.01176471]
#  [0.01176471]]
# (524540, 1)

# %%
print(dataset.shape)
# Out:
# (262270, 2, 5, 1)

# %%
dataset = dataset.reshape((dataset.shape[0]*2, 1, dataset.shape[2], 1))
print(dataset.shape)
# Out:
# (524540, 1, 5, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, datay, test_size=0.10)
print(X_train.shape)
print(y_train.shape)
# Out:
# (472086, 1, 5, 1)
# (472086, 1)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %%
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=( 1,5,1)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
history=model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=2, shuffle=False)
# Out:
# Train on 472086 samples, validate on 52454 samples
# Epoch 1/50
#  - 27s - loss: 8.0744e-04 - val_loss: 8.1401e-04
# Epoch 2/50
#  - 27s - loss: 8.0364e-04 - val_loss: 8.1254e-04
# Epoch 3/50
#  - 27s - loss: 8.0203e-04 - val_loss: 8.1203e-04
# Epoch 4/50
#  - 27s - loss: 8.0070e-04 - val_loss: 8.1075e-04
# Epoch 5/50
#  - 26s - loss: 7.9912e-04 - val_loss: 8.0968e-04
# Epoch 6/50
#  - 25s - loss: 7.9739e-04 - val_loss: 8.0796e-04
# Epoch 7/50
#  - 26s - loss: 7.9626e-04 - val_loss: 8.0814e-04
# Epoch 8/50
#  - 26s - loss: 7.9533e-04 - val_loss: 8.0744e-04
# Epoch 9/50
#  - 26s - loss: 7.9457e-04 - val_loss: 8.0659e-04
# Epoch 10/50
#  - 25s - loss: 7.9393e-04 - val_loss: 8.0703e-04
# Epoch 11/50
#  - 25s - loss: 7.9335e-04 - val_loss: 8.0629e-04
# Epoch 12/50
#  - 25s - loss: 7.9289e-04 - val_loss: 8.0613e-04
# Epoch 13/50
#  - 26s - loss: 7.9254e-04 - val_loss: 8.0547e-04
# Epoch 14/50
#  - 25s - loss: 7.9223e-04 - val_loss: 8.0551e-04
# Epoch 15/50
#  - 25s - loss: 7.9200e-04 - val_loss: 8.0644e-04
# Epoch 16/50
#  - 25s - loss: 7.9192e-04 - val_loss: 8.0566e-04
# Epoch 17/50
#  - 26s - loss: 7.9174e-04 - val_loss: 8.0539e-04
# Epoch 18/50
#  - 26s - loss: 7.9163e-04 - val_loss: 8.0550e-04
# Epoch 19/50
#  - 26s - loss: 7.9151e-04 - val_loss: 8.0546e-04
# Epoch 20/50
#  - 25s - loss: 7.9141e-04 - val_loss: 8.0530e-04
# Epoch 21/50
#  - 26s - loss: 7.9133e-04 - val_loss: 8.0548e-04
# Epoch 22/50
#  - 26s - loss: 7.9125e-04 - val_loss: 8.0487e-04
# Epoch 23/50
#  - 26s - loss: 7.9108e-04 - val_loss: 8.0515e-04
# Epoch 24/50
#  - 25s - loss: 7.9101e-04 - val_loss: 8.0491e-04
# Epoch 25/50
#  - 25s - loss: 7.9095e-04 - val_loss: 8.0492e-04
# Epoch 26/50
#  - 25s - loss: 7.9085e-04 - val_loss: 8.0416e-04
# Epoch 27/50
#  - 25s - loss: 7.9066e-04 - val_loss: 8.0459e-04
# Epoch 28/50
#  - 25s - loss: 7.9061e-04 - val_loss: 8.0455e-04
# Epoch 29/50
#  - 26s - loss: 7.9056e-04 - val_loss: 8.0465e-04
# Epoch 30/50
#  - 26s - loss: 7.9046e-04 - val_loss: 8.0460e-04
# Epoch 31/50
#  - 25s - loss: 7.9041e-04 - val_loss: 8.0464e-04
# Epoch 32/50
#  - 25s - loss: 7.9031e-04 - val_loss: 8.0479e-04
# Epoch 33/50
#  - 26s - loss: 7.9022e-04 - val_loss: 8.0470e-04
# Epoch 34/50
#  - 26s - loss: 7.9012e-04 - val_loss: 8.0446e-04
# Epoch 35/50
#  - 25s - loss: 7.9003e-04 - val_loss: 8.0459e-04
# Epoch 36/50
#  - 25s - loss: 7.9000e-04 - val_loss: 8.0453e-04
# Epoch 37/50
#  - 26s - loss: 7.8988e-04 - val_loss: 8.0446e-04
# Epoch 38/50
#  - 26s - loss: 7.8974e-04 - val_loss: 8.0431e-04
# Epoch 39/50
#  - 26s - loss: 7.8968e-04 - val_loss: 8.0422e-04
# Epoch 40/50
#  - 25s - loss: 7.8961e-04 - val_loss: 8.0413e-04
# Epoch 41/50
#  - 26s - loss: 7.8947e-04 - val_loss: 8.0411e-04
# Epoch 42/50
#  - 25s - loss: 7.8939e-04 - val_loss: 8.0401e-04
# Epoch 43/50
#  - 25s - loss: 7.8931e-04 - val_loss: 8.0395e-04
# Epoch 44/50
#  - 25s - loss: 7.8934e-04 - val_loss: 8.0403e-04
# Epoch 45/50
#  - 25s - loss: 7.8924e-04 - val_loss: 8.0383e-04
# Epoch 46/50
#  - 25s - loss: 7.8921e-04 - val_loss: 8.0367e-04
# Epoch 47/50
#  - 25s - loss: 7.8911e-04 - val_loss: 8.0381e-04
# Epoch 48/50
#  - 25s - loss: 7.8904e-04 - val_loss: 8.0362e-04
# Epoch 49/50
#  - 25s - loss: 7.8906e-04 - val_loss: 8.0366e-04
# Epoch 50/50
#  - 25s - loss: 7.8899e-04 - val_loss: 8.0340e-04

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from math import sqrt
from numpy import concatenate

yhat = model.predict(X_test)
print(yhat)
#X_test = X_test.reshape((X_test.shape[0], X_test.shape[1]))
# invert scaling for forecast
# inv_yhat = concatenate((yhat, test[:, 1:]), axis=1)
# inv=inv_yhat
# inv_yhat = scaler.inverse_transform(inv_yhat)
# inv_yhat = inv_yhat[:,0]
# # invert scaling for actual
# testy = testy.reshape((len(testy), 1))
# inv_y = concatenate((testy, test[:, 1:]), axis=1)
rmse = sqrt(mean_squared_error(y_test, yhat))
print('Test RMSE: %.3f' % rmse)
# inv_y = scaler.inverse_transform(inv_y)
# inv_y = inv_y[:,0]
# # calculate RMSE
# rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
# print('Test RMSE: %.3f' % rmse)
# Out:
# [[0.02459672]
#  [0.01593343]
#  [0.02118316]
#  ...
#  [0.03212906]
#  [0.02459672]
#  [0.01772615]]
# Test RMSE: 0.028
